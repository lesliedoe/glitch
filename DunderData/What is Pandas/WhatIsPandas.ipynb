# %%
import pandas as pd
pd.__version__
# Out:
# '2.0.3'

# %%
import os
os.listdir()
# Out:
# ['average_arrival_delay.csv',
#  'bikes.csv',
#  'insurance.csv',
#  'mdap.mplstyle',
#  'msft20.csv',
#  'neurIPS.db',
#  'planecrashinfo.csv',
#  'sf_employee_compensation.csv',
#  'WhatIsPandas.ipynb',
#  'WhatIsPandas.py']

# %%
#load in bike data
bikes = pd.read_csv(r'bikes.csv')
#return first 3 rows
bikes.head(3)
# Out:
#    trip_id gender            starttime             stoptime  tripduration  \
# 0     7147   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1     7524   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2    10927   Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
#
#               from_station_name  dpcapacity_start          to_station_name  \
# 0     Lake Shore Dr & Monroe St              11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd              31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St              15.0  Dearborn St & Monroe St
#
#    dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 0            15.0         73.9        10.0        12.7        -9999.0
# 1            19.0         69.1        10.0         6.9        -9999.0
# 2            23.0         73.0        10.0        16.1        -9999.0
#
#          events
# 0  mostlycloudy
# 1  partlycloudy
# 2  mostlycloudy

# %%
#Filtering
filt = bikes['tripduration'] > 5000
bikes[filt].head(3)
# Out:
#     trip_id  gender            starttime             stoptime  tripduration  \
# 18    40924    Male  2013-07-09 13:12:00  2013-07-09 14:42:00          5396
# 40    61401  Female  2013-07-14 14:08:00  2013-07-14 15:53:00          6274
# 77    87005  Female  2013-07-21 11:35:00  2013-07-21 13:54:00          8299
#
#             from_station_name  dpcapacity_start               to_station_name  \
# 18    Canal St & Jackson Blvd              35.0               Millennium Park
# 40  Wabash Ave & Roosevelt Rd              19.0     Lake Shore Dr & Monroe St
# 77         State St & 19th St              15.0  Sheffield Ave & Kingsbury St
#
#     dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 18            35.0         79.0        10.0        13.8            0.0
# 40            11.0         87.1        10.0         8.1        -9999.0
# 77            15.0         82.9        10.0         5.8        -9999.0
#
#           events
# 18        cloudy
# 40  partlycloudy
# 77  mostlycloudy

# %%
filt1 = bikes['tripduration'] > 5000
filt2 = bikes['gender'] == 'Female'
#returns tripduratioin >5k AND when female
filtA = filt1 & filt2
bikes[filtA].head(3)
# Out:
#       trip_id  gender            starttime             stoptime  tripduration  \
# 40      61401  Female  2013-07-14 14:08:00  2013-07-14 15:53:00          6274
# 77      87005  Female  2013-07-21 11:35:00  2013-07-21 13:54:00          8299
# 1954  1103416  Female  2013-12-28 11:37:00  2013-12-28 13:34:00          7050
#
#                from_station_name  dpcapacity_start  \
# 40     Wabash Ave & Roosevelt Rd              19.0
# 77            State St & 19th St              15.0
# 1954  LaSalle St & Washington St              15.0
#
#                    to_station_name  dpcapacity_end  temperature  visibility  \
# 40       Lake Shore Dr & Monroe St            11.0         87.1        10.0
# 77    Sheffield Ave & Kingsbury St            15.0         82.9        10.0
# 1954           Theater on the Lake            15.0         44.1        10.0
#
#       wind_speed  precipitation        events
# 40           8.1        -9999.0  partlycloudy
# 77           5.8        -9999.0  mostlycloudy
# 1954        12.7        -9999.0         clear

# %%
#returns tripuduration >5k OR when female
filtB = filt1 | filt2
bikes[filtB].head(3)
# Out:
#     trip_id  gender            starttime             stoptime  tripduration  \
# 9     23558  Female  2013-07-04 15:00:00  2013-07-04 15:16:00           922
# 14    31121  Female  2013-07-06 12:39:00  2013-07-06 12:49:00           610
# 18    40924    Male  2013-07-09 13:12:00  2013-07-09 14:42:00          5396
#
#                 from_station_name  dpcapacity_start  \
# 9   Lakeview Ave & Fullerton Pkwy              19.0
# 14            Morgan St & Lake St              15.0
# 18        Canal St & Jackson Blvd              35.0
#
#                to_station_name  dpcapacity_end  temperature  visibility  \
# 9   Racine Ave & Congress Pkwy            19.0         81.0        10.0
# 14  Aberdeen St & Jackson Blvd            15.0         82.0        10.0
# 18             Millennium Park            35.0         79.0        10.0
#
#     wind_speed  precipitation        events
# 9         12.7        -9999.0  mostlycloudy
# 14         5.8        -9999.0  mostlycloudy
# 18        13.8            0.0        cloudy

# %%
bikes.query('tripduration > 5000').head(3)
# Out:
#     trip_id  gender            starttime             stoptime  tripduration  \
# 18    40924    Male  2013-07-09 13:12:00  2013-07-09 14:42:00          5396
# 40    61401  Female  2013-07-14 14:08:00  2013-07-14 15:53:00          6274
# 77    87005  Female  2013-07-21 11:35:00  2013-07-21 13:54:00          8299
#
#             from_station_name  dpcapacity_start               to_station_name  \
# 18    Canal St & Jackson Blvd              35.0               Millennium Park
# 40  Wabash Ave & Roosevelt Rd              19.0     Lake Shore Dr & Monroe St
# 77         State St & 19th St              15.0  Sheffield Ave & Kingsbury St
#
#     dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 18            35.0         79.0        10.0        13.8            0.0
# 40            11.0         87.1        10.0         8.1        -9999.0
# 77            15.0         82.9        10.0         5.8        -9999.0
#
#           events
# 18        cloudy
# 40  partlycloudy
# 77  mostlycloudy

# %%
bikes.query('tripduration > 5000 and gender =="Female"').head(3)
# Out:
#       trip_id  gender            starttime             stoptime  tripduration  \
# 40      61401  Female  2013-07-14 14:08:00  2013-07-14 15:53:00          6274
# 77      87005  Female  2013-07-21 11:35:00  2013-07-21 13:54:00          8299
# 1954  1103416  Female  2013-12-28 11:37:00  2013-12-28 13:34:00          7050
#
#                from_station_name  dpcapacity_start  \
# 40     Wabash Ave & Roosevelt Rd              19.0
# 77            State St & 19th St              15.0
# 1954  LaSalle St & Washington St              15.0
#
#                    to_station_name  dpcapacity_end  temperature  visibility  \
# 40       Lake Shore Dr & Monroe St            11.0         87.1        10.0
# 77    Sheffield Ave & Kingsbury St            15.0         82.9        10.0
# 1954           Theater on the Lake            15.0         44.1        10.0
#
#       wind_speed  precipitation        events
# 40           8.1        -9999.0  partlycloudy
# 77           5.8        -9999.0  mostlycloudy
# 1954        12.7        -9999.0         clear

# %%
bikes.query('tripduration > 5000 or gender=="Female"').head(3)
# Out:
#     trip_id  gender            starttime             stoptime  tripduration  \
# 9     23558  Female  2013-07-04 15:00:00  2013-07-04 15:16:00           922
# 14    31121  Female  2013-07-06 12:39:00  2013-07-06 12:49:00           610
# 18    40924    Male  2013-07-09 13:12:00  2013-07-09 14:42:00          5396
#
#                 from_station_name  dpcapacity_start  \
# 9   Lakeview Ave & Fullerton Pkwy              19.0
# 14            Morgan St & Lake St              15.0
# 18        Canal St & Jackson Blvd              35.0
#
#                to_station_name  dpcapacity_end  temperature  visibility  \
# 9   Racine Ave & Congress Pkwy            19.0         81.0        10.0
# 14  Aberdeen St & Jackson Blvd            15.0         82.0        10.0
# 18             Millennium Park            35.0         79.0        10.0
#
#     wind_speed  precipitation        events
# 9         12.7        -9999.0  mostlycloudy
# 14         5.8        -9999.0  mostlycloudy
# 18        13.8            0.0        cloudy

# %%
cols = ['salaries', 'overtime', 'other salaries', 'retirement', 'health and dental']
sf_emp = pd.read_csv(r'sf_employee_compensation.csv', usecols=cols)
sf_emp.head(3)
# Out:
#     salaries  overtime  other salaries  retirement  health and dental
# 0   71414.01      0.00             0.0    14038.58           12918.24
# 1   67941.06      0.00             0.0    13030.23           10047.52
# 2  116956.72  59975.43         19037.3    24796.44           15788.97

# %%
#returns the mean of each column
sf_emp.mean()
# Out:
# salaries             53715.441133
# overtime              4201.272687
# other salaries        2816.296542
# retirement           10484.755614
# health and dental     9382.390735
# dtype: float64

# %%
#aggregates rows by using the axis. returns total comp for each employee
sf_emp.sum(axis=1).head(3)
# Out:
# 0     98370.83
# 1     91018.81
# 2    236554.86
# dtype: float64

# %%
ins = pd.read_csv(r'insurance.csv')
ins.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
ins['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
ins.groupby('sex').agg(mean_charges=('charges', 'mean')).round(-3)
# Out:
#         mean_charges
# sex
# female       13000.0
# male         14000.0

# %%
ins.groupby('sex').agg(mean_charges=('charges','mean'),
                       max_charges=('charges', 'max'),
                       count_charges=('charges', 'count')).round(0)
# Out:
#         mean_charges  max_charges  count_charges
# sex
# female       12570.0      63770.0            662
# male         13957.0      62593.0            676

# %%
ins.groupby(['sex', 'region']).agg(mean_charges=('charges', 'mean'),
                                   max_charges=('charges', 'max'),
                                   count_charges=('charges', 'count')).round(0)
# Out:
#                   mean_charges  max_charges  count_charges
# sex    region
# female northeast       12953.0      58571.0            161
#        northwest       12480.0      55135.0            164
#        southeast       13500.0      63770.0            175
#        southwest       11274.0      48824.0            162
# male   northeast       13854.0      48549.0            163
#        northwest       12354.0      60021.0            161
#        southeast       15880.0      62593.0            189
#        southwest       13413.0      52591.0            163

# %%
pt = ins.pivot_table(index='sex', columns='region', 
                     values='charges', aggfunc='mean').round(0)
pt
# Out:
# region  northeast  northwest  southeast  southwest
# sex
# female    12953.0    12480.0    13500.0    11274.0
# male      13854.0    12354.0    15880.0    13413.0

# %%
pt.style.highlight_max().format(r'{:,.0f}')
# Out:
# <style type="text/css">
# #T_082be_row0_col1, #T_082be_row1_col0, #T_082be_row1_col2, #T_082be_row1_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_082be">
#   <thead>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th id="T_082be_level0_col0" class="col_heading level0 col0" >northeast</th>
#       <th id="T_082be_level0_col1" class="col_heading level0 col1" >northwest</th>
#       <th id="T_082be_level0_col2" class="col_heading level0 col2" >southeast</th>
#       <th id="T_082be_level0_col3" class="col_heading level0 col3" >southwest</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_082be_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_082be_row0_col0" class="data row0 col0" >12,953</td>
#       <td id="T_082be_row0_col1" class="data row0 col1" >12,480</td>
#       <td id="T_082be_row0_col2" class="data row0 col2" >13,500</td>
#       <td id="T_082be_row0_col3" class="data row0 col3" >11,274</td>
#     </tr>
#     <tr>
#       <th id="T_082be_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_082be_row1_col0" class="data row1 col0" >13,854</td>
#       <td id="T_082be_row1_col1" class="data row1 col1" >12,354</td>
#       <td id="T_082be_row1_col2" class="data row1 col2" >15,880</td>
#       <td id="T_082be_row1_col3" class="data row1 col3" >13,413</td>
#     </tr>
#   </tbody>
# </table>

# %%
pc = pd.read_csv(r'planecrashinfo.csv')
pc.head(3)
# Out:
#                  date   time                   location              operator  \
# 0  September 17, 1908  17:18        Fort Myer, Virginia  Military - U.S. Army
# 1  September 07, 1909      ?    Juvisy-sur-Orge, France                     ?
# 2       July 12, 1912  06:30  Atlantic City, New Jersey  Military - U.S. Navy
#
#   flight_no          route           ac_type registration cn_ln  \
# 0         ?  Demonstration  Wright Flyer III            ?     1
# 1         ?       Air show    Wright Byplane          SC1     ?
# 2         ?    Test flight         Dirigible            ?     ?
#
#                        aboard                  fatalities ground  \
# 0  2   (passengers:1  crew:1)  1   (passengers:1  crew:0)      0
# 1  1   (passengers:0  crew:1)  1   (passengers:0  crew:0)      0
# 2  5   (passengers:0  crew:5)  5   (passengers:0  crew:5)      0
#
#                                              summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  Eugene Lefebvre was the first pilot to ever be...
# 2  First U.S. dirigible Akron exploded just offsh...

# %%
pc = pd.read_csv(r'planecrashinfo.csv', na_values='?')
pc.head(3)
# Out:
#                  date   time                   location              operator  \
# 0  September 17, 1908  17:18        Fort Myer, Virginia  Military - U.S. Army
# 1  September 07, 1909    NaN    Juvisy-sur-Orge, France                   NaN
# 2       July 12, 1912  06:30  Atlantic City, New Jersey  Military - U.S. Navy
#
#   flight_no          route           ac_type registration cn_ln  \
# 0       NaN  Demonstration  Wright Flyer III          NaN     1
# 1       NaN       Air show    Wright Byplane          SC1   NaN
# 2       NaN    Test flight         Dirigible          NaN   NaN
#
#                        aboard                  fatalities  ground  \
# 0  2   (passengers:1  crew:1)  1   (passengers:1  crew:0)     0.0
# 1  1   (passengers:0  crew:1)  1   (passengers:0  crew:0)     0.0
# 2  5   (passengers:0  crew:5)  5   (passengers:0  crew:5)     0.0
#
#                                              summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  Eugene Lefebvre was the first pilot to ever be...
# 2  First U.S. dirigible Akron exploded just offsh...

# %%
aboard = pc['aboard']
aboard.head()
# Out:
# 0     2   (passengers:1  crew:1)
# 1     1   (passengers:0  crew:1)
# 2     5   (passengers:0  crew:5)
# 3     1   (passengers:0  crew:1)
# 4    20   (passengers:?  crew:?)
# Name: aboard, dtype: object

# %%
aboard.str.extract(r'(\d+)?\D*(\d+)?\D*(\d+)?').head()
# Out:
#     0    1    2
# 0   2    1    1
# 1   1    0    1
# 2   5    0    5
# 3   1    0    1
# 4  20  NaN  NaN

# %%
aad = pd.read_csv(r'average_arrival_delay.csv').head()
aad
# Out:
#   airline  ATL  IAH  LAX  SFO
# 0      AA    4   11    3    3
# 1      DL    0    3    3    0
# 2      UA    5    9    4    5

# %%
#stacks columns on top of the other.
aad.melt(id_vars='airline', var_name='airport', value_name='delay').head(10)
# Out:
#   airline airport  delay
# 0      AA     ATL      4
# 1      DL     ATL      0
# 2      UA     ATL      5
# 3      AA     IAH     11
# 4      DL     IAH      3
# 5      UA     IAH      9
# 6      AA     LAX      3
# 7      DL     LAX      3
# 8      UA     LAX      4
# 9      AA     SFO      3

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///neurIPS.db')

# %%
authors = pd.read_sql('Authors', engine)
pa = pd.read_sql('PaperAuthors', engine)

# %%
authors.head(3)
# Out:
#     Id           Name
# 0  178  Yoshua Bengio
# 1  200     Yann LeCun
# 2  205     Avrim Blum

# %%
pa.head(3)
# Out:
#    Id  PaperId  AuthorId
# 0   1     5677      7956
# 1   2     5677      2649
# 2   3     5941      8299

# %%
pa.merge(authors, how='left', left_on='AuthorId', right_on='Id').head(3)
# Out:
#    Id_x  PaperId  AuthorId  Id_y                 Name
# 0     1     5677      7956  7956  Nihar Bhadresh Shah
# 1     2     5677      2649  2649           Denny Zhou
# 2     3     5941      8299  8299   Brendan van Rooyen

# %%
msft = pd.read_csv(r'msft20.csv', parse_dates=['date'], index_col='date')
msft.head()
# Out:
#               open    high     low   close  adjusted_close    volume  \
# date
# 1999-10-19  88.250  89.250  85.250  86.313         27.8594  69945600
# 1999-10-20  91.563  92.375  90.250  92.250         29.7758  88090600
# 1999-10-21  90.563  93.125  90.500  93.063         30.0381  60801200
# 1999-10-22  93.563  93.875  91.750  92.688         29.9171  43650600
# 1999-10-25  92.000  93.563  91.125  92.438         29.8364  30492200
#
#             dividend_amount
# date
# 1999-10-19              0.0
# 1999-10-20              0.0
# 1999-10-21              0.0
# 1999-10-22              0.0
# 1999-10-25              0.0

# %%
msft['2017-02-27':'2017-03-02']
# Out:
#              open   high     low  close  adjusted_close    volume  \
# date
# 2017-02-27  64.54  64.54  64.045  64.23         61.4355  15871500
# 2017-02-28  64.08  64.20  63.760  63.98         61.1964  23239800
# 2017-03-01  64.13  64.99  64.022  64.94         62.1146  26937500
# 2017-03-02  64.69  64.75  63.880  64.01         61.2251  24539600
#
#             dividend_amount
# date
# 2017-02-27              0.0
# 2017-02-28              0.0
# 2017-03-01              0.0
# 2017-03-02              0.0

# %%
msft_mc = msft.resample('M').agg({'close':'mean'})
msft_mc.head(3)
# Out:
#                  close
# date
# 1999-10-31   91.382222
# 1999-11-30   89.463762
# 1999-12-31  106.190545

# %%
#pip3install matplotlib
import matplotlib.pyplot as plt
plt.style.use(r'mdap.mplstyle')
msft_mc.plot(kind='line');

# %%
aad.plot(kind='box')
# Out:
# <Axes: >

# %%
pt.plot(kind='bar', rot=0).legend(bbox_to_anchor=(1, 1), loc='upper left');
