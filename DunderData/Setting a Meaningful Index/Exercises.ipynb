# %%
import pandas as pd
movie = pd.read_csv(r'movie.csv')

# %%
movie.set_index('year').head(3)
#there are no other good columns to use as index outside of
#title which we were old not to use. This is because every other
#column contains dups.
# Out:
#                                            title  color content_rating  \
# year
# 2009.0                                    Avatar  Color          PG-13
# 2007.0  Pirates of the Caribbean: At World's End  Color          PG-13
# 2015.0                                   Spectre  Color          PG-13
#
#         duration   director_name  director_fb           actor1  actor1_fb  \
# year
# 2009.0     178.0   James Cameron          0.0      CCH Pounder     1000.0
# 2007.0     169.0  Gore Verbinski        563.0      Johnny Depp    40000.0
# 2015.0     148.0      Sam Mendes          0.0  Christoph Waltz    11000.0
#
#                   actor2  actor2_fb  ... actor3_fb        gross  \
# year                                 ...
# 2009.0  Joel David Moore      936.0  ...     855.0  760505847.0
# 2007.0     Orlando Bloom     5000.0  ...    1000.0  309404152.0
# 2015.0      Rory Kinnear      393.0  ...     161.0  200074175.0
#
# ...

# %%
def exercise_2():
    inx = movie.reset_index().set_index('title')
    print(inx)

# %%
exercise_2()
# Out:
#                                             index    year  color  \
# title
# Avatar                                          0  2009.0  Color
# Pirates of the Caribbean: At World's End        1  2007.0  Color
# Spectre                                         2  2015.0  Color
# The Dark Knight Rises                           3  2012.0  Color
# Star Wars: Episode VII - The Force Awakens      4     NaN    NaN
# ...                                           ...     ...    ...
# Signed Sealed Delivered                      4911  2013.0  Color
# The Following                                4912     NaN  Color
# A Plague So Pleasant                         4913  2013.0  Color
# Shanghai Calling                             4914  2012.0  Color
# My Date with Drew                            4915  2004.0  Color
#
#                                            content_rating  duration  \
# title
# Avatar                                              PG-13     178.0
# ...

# %%
def exercise_3():
    movie = pd.read_csv(r'movie.csv', index_col='title')
    print(movie.tail(10))

# %%
exercise_3()
# Out:
#                            year  color content_rating  duration  \
# title
# Primer                   2004.0  Color          PG-13      77.0
# Cavite                   2005.0  Color      Not Rated      80.0
# El Mariachi              1992.0  Color              R      81.0
# The Mongol King          2005.0  Color          PG-13      84.0
# Newlyweds                2011.0  Color      Not Rated      95.0
# Signed Sealed Delivered  2013.0  Color            NaN      87.0
# The Following               NaN  Color          TV-14      43.0
# A Plague So Pleasant     2013.0  Color            NaN      76.0
# Shanghai Calling         2012.0  Color          PG-13     100.0
# My Date with Drew        2004.0  Color             PG      90.0
#
#                             director_name  director_fb           actor1  \
# title
# Primer                      Shane Carruth        291.0    Shane Carruth
# Cavite                   Neill Dela Llana          0.0      Ian Gamazon
# ...

# %%
movie2 = pd.read_csv(r'movie.csv', index_col=0)
print(movie2)
#changing from column name to integer does the
#same thing as long as you select the right position
#left to right starting at 0
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# ...                                            ...    ...            ...
# Signed Sealed Delivered                     2013.0  Color            NaN
# The Following                                  NaN  Color          TV-14
# A Plague So Pleasant                        2013.0  Color            NaN
# Shanghai Calling                            2012.0  Color          PG-13
# My Date with Drew                           2004.0  Color             PG
#
#                                             duration      director_name  \
# title
# ...
