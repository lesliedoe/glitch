# %%
import pandas as pd

# %%
bikes = pd.read_csv(r'bikes.csv')

# %%
bikes
# Out:
#         trip_id  gender            starttime             stoptime  \
# 0          7147    Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1          7524    Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2         10927    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3         12907    Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4         13168    Male  2013-07-01 11:16:00  2013-07-01 11:18:00
# ...         ...     ...                  ...                  ...
# 50084  17534938    Male  2017-12-30 13:07:00  2017-12-30 13:34:00
# 50085  17534969    Male  2017-12-30 13:34:00  2017-12-30 13:44:00
# 50086  17534972    Male  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246    Male  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration             from_station_name  dpcapacity_start  \
# 0               993     Lake Shore Dr & Monroe St              11.0
# 1               623  Clinton St & Washington Blvd              31.0
# 2              1040  Sheffield Ave & Kingsbury St              15.0
# 3               667       Carpenter St & Huron St              19.0
# 4               130        Damen Ave & Pierce Ave              19.0
# ...             ...                           ...               ...
# 50084          1625         State St & Pearson St              27.0
# 50085           585      Halsted St & 35th St (*)              16.0
# 50086           824      Kingsbury St & Kinzie St              31.0
# 50087           178          Clinton St & Lake St              23.0
# 50088           214    Clarendon Ave & Leland Ave              15.0
#
#                      to_station_name  dpcapacity_end  temperature  visibility  \
# 0              Michigan Ave & Oak St            15.0         73.9        10.0
# 1               Wells St & Walton St            19.0         69.1        10.0
# 2            Dearborn St & Monroe St            23.0         73.0        10.0
# 3             Clark St & Randolph St            31.0         72.0        10.0
# 4             Damen Ave & Pierce Ave            19.0         73.0        10.0
# ...                              ...             ...          ...         ...
# 50084              Clark St & Elm St            27.0          5.0        10.0
# 50085            Union Ave & Root St            11.0          5.0        10.0
# 50086  Halsted St & Blackhawk St (*)            20.0          5.0        10.0
# 50087       Kingsbury St & Kinzie St            31.0          7.0        10.0
# 50088     Clifton Ave & Lawrence Ave            15.0         10.9        10.0
#
#        wind_speed  precipitation        events
# 0            12.7        -9999.0  mostlycloudy
# 1             6.9        -9999.0  partlycloudy
# 2            16.1        -9999.0  mostlycloudy
# 3            16.1        -9999.0  mostlycloudy
# 4            17.3        -9999.0  partlycloudy
# ...           ...            ...           ...
# 50084        16.1        -9999.0  partlycloudy
# 50085        16.1        -9999.0  partlycloudy
# 50086        16.1        -9999.0  partlycloudy
# 50087        11.5        -9999.0  partlycloudy
# 50088        15.0        -9999.0  partlycloudy
#
# [50089 rows x 14 columns]

# %%
bikes.head()
# Out:
#    trip_id gender            starttime             stoptime  tripduration  \
# 0     7147   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1     7524   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2    10927   Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 3    12907   Male  2013-07-01 10:05:00  2013-07-01 10:16:00           667
# 4    13168   Male  2013-07-01 11:16:00  2013-07-01 11:18:00           130
#
#               from_station_name  dpcapacity_start          to_station_name  \
# 0     Lake Shore Dr & Monroe St              11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd              31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St              15.0  Dearborn St & Monroe St
# 3       Carpenter St & Huron St              19.0   Clark St & Randolph St
# 4        Damen Ave & Pierce Ave              19.0   Damen Ave & Pierce Ave
#
#    dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 0            15.0         73.9        10.0        12.7        -9999.0
# 1            19.0         69.1        10.0         6.9        -9999.0
# 2            23.0         73.0        10.0        16.1        -9999.0
# 3            31.0         72.0        10.0        16.1        -9999.0
# 4            19.0         73.0        10.0        17.3        -9999.0
#
#          events
# 0  mostlycloudy
# 1  partlycloudy
# 2  mostlycloudy
# 3  mostlycloudy
# 4  partlycloudy

# %%
bikes.tail()
# Out:
#         trip_id  gender            starttime             stoptime  \
# 50084  17534938    Male  2017-12-30 13:07:00  2017-12-30 13:34:00
# 50085  17534969    Male  2017-12-30 13:34:00  2017-12-30 13:44:00
# 50086  17534972    Male  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246    Male  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration           from_station_name  dpcapacity_start  \
# 50084          1625       State St & Pearson St              27.0
# 50085           585    Halsted St & 35th St (*)              16.0
# 50086           824    Kingsbury St & Kinzie St              31.0
# 50087           178        Clinton St & Lake St              23.0
# 50088           214  Clarendon Ave & Leland Ave              15.0
#
#                      to_station_name  dpcapacity_end  temperature  visibility  \
# 50084              Clark St & Elm St            27.0          5.0        10.0
# 50085            Union Ave & Root St            11.0          5.0        10.0
# 50086  Halsted St & Blackhawk St (*)            20.0          5.0        10.0
# 50087       Kingsbury St & Kinzie St            31.0          7.0        10.0
# 50088     Clifton Ave & Lawrence Ave            15.0         10.9        10.0
#
#        wind_speed  precipitation        events
# 50084        16.1        -9999.0  partlycloudy
# 50085        16.1        -9999.0  partlycloudy
# 50086        16.1        -9999.0  partlycloudy
# 50087        11.5        -9999.0  partlycloudy
# 50088        15.0        -9999.0  partlycloudy

# %%
bikes.head(3)
# Out:
#    trip_id gender            starttime             stoptime  tripduration  \
# 0     7147   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1     7524   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2    10927   Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
#
#               from_station_name  dpcapacity_start          to_station_name  \
# 0     Lake Shore Dr & Monroe St              11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd              31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St              15.0  Dearborn St & Monroe St
#
#    dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 0            15.0         73.9        10.0        12.7        -9999.0
# 1            19.0         69.1        10.0         6.9        -9999.0
# 2            23.0         73.0        10.0        16.1        -9999.0
#
#          events
# 0  mostlycloudy
# 1  partlycloudy
# 2  mostlycloudy

# %%
type(bikes)
# Out:
# pandas.core.frame.DataFrame

# %%
import site
site.getsitepackages()
# Out:
# ['c:\\Users\\mcphe\\AppData\\Local\\Programs\\Python\\Python311',
#  'c:\\Users\\mcphe\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages']

# %%
td = bikes['tripduration']
td.head()
# Out:
# 0     993
# 1     623
# 2    1040
# 3     667
# 4     130
# Name: tripduration, dtype: int64

# %%
td.tail(3)
# Out:
# 50086    824
# 50087    178
# 50088    214
# Name: tripduration, dtype: int64

# %%
type(td)
# Out:
# pandas.core.series.Series

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.get_option('display.max_colwidth')
# Out:
# 50

# %%
pd.set_option('display.max_columns', 100, 'display.max_rows', 4)

# %%
housing = pd.read_csv(r'housing.csv')
housing
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# ...          ...       ...       ...       ...          ...        ...
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# ...         ...      ...        ...          ...          ...        ...
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd        NaN
# ...            ...       ...      ...         ...         ...        ...
# 1458          1996       Hip  CompShg     MetalSd     MetalSd        NaN
# 1459          1965     Gable  CompShg     HdBoard     HdBoard        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# ...           ...          ...         ...          ...         ...
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# ...        ...       ...           ...        ...           ...           ...
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# ...        ...       ...           ...           ...         ...
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# ...            ...        ...         ...         ...        ...          ...
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# ...          ...          ...            ...        ...          ...
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN   NaN         NaN        0       2    2008       WD
# 1            0    NaN   NaN         NaN        0       5    2007       WD
# ...        ...    ...   ...         ...      ...     ...     ...      ...
# 1458         0    NaN   NaN         NaN        0       4    2010       WD
# 1459         0    NaN   NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice
# 0           Normal     208500
# 1           Normal     181500
# ...            ...        ...
# 1458        Normal     142125
# 1459        Normal     147500
#
# [1460 rows x 81 columns]
